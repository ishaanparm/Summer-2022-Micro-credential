# %% [markdown]
# # COVID 19 Data Analysis

# %% [markdown]
# **Description:** This script will read the latest data from the New York Times' county-level COVID-19 database at https://github.com/nytimes/covid-19-data/blob/master/us-counties.csv, filter the data for a chosen county in a chosen state, calculate the daily count of new cases and new deaths, print the most recent 28 days' worth of data for the selected county, and save the county's data for all dates to a comma-separated value (.csv) file on your computer. The printed data can be copied and pasted directly into a spreadsheet for further analysis and visualization.
#
# **Note:** For information about the data, see https://github.com/nytimes/covid-19-data.
#
# **Note:** After you have run the script one time in a given Anaconda environment, you may reduce the script's execution time by adding a `#` in front of `pip install pandas`. For example, `#pip install pandas` instead of `pip install pandas`. The `#` will tell Python to skip the code without running it.

# %% [markdown]
# # Task 1 : Environment Set up

# %% [markdown]
# Import all required libraries that are needed for data analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style

# %% [markdown]
# # Task 2 :  Data Collection

# %% [markdown]
# Use nytimes github repository as a data source to collect the covid 19 data in real time and ingest it into colab notebook for data anlysis purpose

# %%
df = pd.read_csv('https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-states.csv')

# %%
df.head()
# Out:
#          date       state  fips  cases  deaths
# 0  2020-01-21  Washington    53      1       0
# 1  2020-01-22  Washington    53      1       0
# 2  2020-01-23  Washington    53      1       0
# 3  2020-01-24    Illinois    17      1       0
# 4  2020-01-24  Washington    53      1       0

# %%
df.shape
# Out:
# (15414, 5)

# %%
df.columns
# Out:
# Index(['date', 'state', 'fips', 'cases', 'deaths'], dtype='object')

# %% [markdown]
# # Task 3 : Data Wrangling and EDA (Exploratory Data Analysis)

# %% [markdown]
# Analyzing New York state data for Covid 19

# %%
ny_df = df[df['state']=='New York']

# %%
ny_df.head()
# Out:
#            date     state  fips  cases  deaths
# 246  2020-03-01  New York    36      1       0
# 261  2020-03-02  New York    36      1       0
# 276  2020-03-03  New York    36      2       0
# 293  2020-03-04  New York    36     11       0
# 313  2020-03-05  New York    36     22       0

# %%
ny_df.shape
# Out:
# (282, 5)

# %%
ny_df.tail()
# Out:
#              date     state  fips   cases  deaths
# 15172  2020-12-03  New York    36  678869   34346
# 15227  2020-12-04  New York    36  690143   34409
# 15282  2020-12-05  New York    36  700902   34488
# 15337  2020-12-06  New York    36  710612   34552
# 15392  2020-12-07  New York    36  717930   34637

# %%
#first death in NY
first_ny_death = ny_df[ny_df['deaths']!=0]
first_ny_death.head()
# Out:
#            date     state  fips  cases  deaths
# 669  2020-03-14  New York    36    610       2
# 722  2020-03-15  New York    36    732       6
# 775  2020-03-16  New York    36    950      10
# 828  2020-03-17  New York    36   1375      18
# 882  2020-03-18  New York    36   2387      32

# %%
#total number of cases
ny_df['cases'].max()
# Out:
# 717930

# %%
# not a correct way of calculating total count bcoz data is cumulative
ny_df['cases'].sum()
# Out:
# 105935210

# %% [markdown]
# Finding new covid 19 cases on daily basis (new cases added everyday)

# %%
#new cases for NY
# type(ny_df['cases'])

newcase = []
previuos_case = 0
for index, row in ny_df.iterrows():
  current_case = row['cases']
  newcase_count = current_case - previuos_case
  previuos_case = current_case
  newcase.append(newcase_count)
  # print(newcase_count)

# %%
ny_df['new_cases'] = newcase
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
ny_df.head(10)
# Out:
#            date     state  fips  cases  deaths  new_cases
# 246  2020-03-01  New York    36      1       0          1
# 261  2020-03-02  New York    36      1       0          0
# 276  2020-03-03  New York    36      2       0          1
# 293  2020-03-04  New York    36     11       0          9
# 313  2020-03-05  New York    36     22       0         11
# 338  2020-03-06  New York    36     44       0         22
# 369  2020-03-07  New York    36     89       0         45
# 404  2020-03-08  New York    36    106       0         17
# 440  2020-03-09  New York    36    142       0         36
# 478  2020-03-10  New York    36    173       0         31

# %%
ny_df['new_cases'].sum()
# Out:
# 717930

# %%
ny_cases = ny_df['cases']
ny_deaths = ny_df['deaths']
ny_dates = ny_df['date']
ny_new_cases = ny_df['new_cases']

# %%
type(ny_new_cases)
# Out:
# pandas.core.series.Series

# %%
ny_df.plot(kind='bar')

# %%
plt.figure(figsize=(15,7))
plt.bar(x=ny_dates, height=ny_new_cases, color='red')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Task4: Understand NY covid 19 data in last 30 days

# %%
ny_cases_30 = ny_df['cases'][-31:-1]
ny_deaths_30 = ny_df['deaths'] [-31:-1]
ny_dates_30 = ny_df['date'][-31:-1]
ny_new_cases_30 = ny_df['new_cases'][-31:-1]

# %%
# ny_dates_30

# %%
plt.figure(figsize=(15,7))
plt.bar(x=ny_dates_30, height=ny_new_cases_30, color='red')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,7))
plt.bar(x=ny_dates_30, height=ny_deaths_30, color='blue')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Comparing Covid 19 data with different states

# %% [markdown]
# Let's compare the Covid 19 cases after July for states: New York, California, Florida, Texas, Arizona

# %%
states = ['New York', 'California','Florida', 'Texas','Arizona']

# %%
plt.figure(figsize=(15,7))
for state in states:
  df_st = df[(df['state']==state) & (df['date']>='2020-11-01')]
  plt.plot(df_st['date'],
           df_st['cases'],
           linewidth=2
           )
  plt.xticks(rotation=90)
plt.legend(states)
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns
sns.set()
df = pd.read_csv('https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-states.csv')
ny_df = df[df['state']=='New York']

states = ['New York', 'Delaware','New Jersey', 'Pennsylvania','Maryland']

plt.figure(figsize=(15,7))
for state in states:
  df_st = df[(df['state']==state) & (df['date']>='2020-11-01')]
  plt.plot(df_st['date'],
           df_st['deaths'],
           linewidth=2
           )
  plt.xticks(rotation=90)
plt.legend(states)
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns
sns.set()
df = pd.read_csv('https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-states.csv')
ny_df = df[df['state']=='New York']

states = ['California', 'Oregon','Washington', 'Idaho','Nevada']

plt.figure(figsize=(15,7))
for state in states:
  df_st = df[(df['state']==state) & (df['date']>='2020-11-01')]
  plt.plot(df_st['date'],
           df_st['cases'],
           linewidth=2
           )
  plt.xticks(rotation=90)
plt.legend(states)
plt.show()

# %% [markdown]
# # Conclusion

# %% [markdown]
# Conclusion 1: Cases appear to have been rising for the last 100 days, most likely due to a more contagious variant of Covid-19 being spread across the world.
#
# Conclusion 2: It appears that Arizona had a much better time in containing the outbreak as opposed to much bigger and more populated states like California and Texas. You can see in the graphs that there are big sudden jumps for those states. Meanwhile, Arizona can manage these bumps, which are new waves, more efficiently and keep the numbers down despite the increased transmissibility.
#
# Conclusion 3: Out of the selected northeastern states, Delaware had the lowest amounts of deaths, while New York had the highest amount. This makes sense as Delaware has the lowest population of the 5 states. Pennsylvania and New Jersey seem to have more cases as opposed to Delaware and Maryland, which could be attributed to their close vicinity to New York, a major transport and commuter hub.
#
# Conclusion 4: Out of the 5 continental western states, California had a much higher number of cases and its' recent case numbers were much more volatile compared to the other western states. It also must be considered that California's population is more than double than the other 4 western states' populations combined while, New York had a large exponential increase in the total number of cases in the winter of 2021. There has been steady exponential increase in the last 100 days, with cases rising from 100,000 to 1,000,000 quickly.
