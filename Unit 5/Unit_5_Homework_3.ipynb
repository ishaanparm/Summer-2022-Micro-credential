# %% [markdown]
# Create a table with the following parameters:
#
# CustomerID
#
# CustomerName
#
# Address
#
# City
#
# PostalCode
#
# Country
#
# Email

# %% [markdown]
# ![HW 3 1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Use an UPDATE to modify any portion of the data

# %% [markdown]
# ![HW 3 2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Finally, write a statement to delete one row of data.

# %% [markdown]
# ![HW 3 3.jpg](data:image/jpeg;base64,...)
